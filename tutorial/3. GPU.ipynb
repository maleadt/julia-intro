# %% [markdown]
# # CUDAnative.jl

# %% [markdown]
# Just another package, no changes to Julia itself.

# %%
using CUDAnative

# %%
function vadd(a, b, c)
    i = (blockIdx().x-1) * blockDim().x + threadIdx().x
    c[i] = a[i] + b[i]
end
# Out:
# vadd (generic function with 1 method)

# %%
using CuArrays

# %%
a = CuArray([1,2,3])
b = CuArray([4,5,6])
c = zero(a)
# Out:
# 3-element CuArray{Int64,1}:
#  0
#  0
#  0

# %%
@cuda threads=length(a) vadd(a, b, c)
c
# Out:
# 3-element CuArray{Int64,1}:
#  5
#  7
#  9

# %%
@device_code_ptx @cuda threads=length(a) vadd(a, b, c)
# Out:
# //
# // Generated by LLVM NVPTX Back-End
# //
#
# .version 6.0
# .target sm_35
# .address_size 64
#
# .extern .func  (.param .b32 func_retval0) vprintf
# (
# 	.param .b64 vprintf_param_0,
# 	.param .b64 vprintf_param_1
# )
# ;
# .func ptx_throw_boundserror
# ()
# ;
# .extern .func jl_gc_queue_root
# (
# 	.param .b64 jl_gc_queue_root_param_0
# )
# ;
# .extern .func  (.param .b64 func_retval0) jl_gc_pool_alloc
# (
# 	.param .b64 jl_gc_pool_alloc_param_0,
# 	.param .b32 jl_gc_pool_alloc_param_1,
# 	.param .b32 jl_gc_pool_alloc_param_2
# )
# ;
# .extern .func  (.param .b64 func_retval0) jl_gc_big_alloc
# (
# 	.param .b64 jl_gc_big_alloc_param_0,
# 	.param .b64 jl_gc_big_alloc_param_1
# )
# ;
# .global .align 1 .b8 __unnamed_1[41] = {69, 82, 82, 79, 82, 58, 32, 97, 32, 98, 111, 117, 110, 100, 115, 101, 114, 114, 111, 114, 32, 101, 120, 99, 101, 112, 116, 105, 111, 110, 32, 111, 99, 99, 117, 114, 114, 101, 100, 10, 0};
#                                         // -- Begin function julia_vadd_37900
#                                         // @julia_vadd_37900
# .func julia_vadd_37900(
# 	.param .b64 julia_vadd_37900_param_0,
# 	.param .b64 julia_vadd_37900_param_1,
# 	.param .b64 julia_vadd_37900_param_2
# )
# {
# 	.reg .pred 	%p<4>;
# 	.reg .b32 	%r<5>;
# 	.reg .b64 	%rd<34>;
#
# // %bb.0:                               // %top
# 	ld.param.u64 	%rd7, [julia_vadd_37900_param_1];
# 	ld.param.u64 	%rd6, [julia_vadd_37900_param_0];
# 	mov.u32 	%r2, %ctaid.x;
# 	mov.u32 	%r3, %ntid.x;
# 	mul.wide.u32 	%rd1, %r3, %r2;
# 	mov.u32 	%r1, %tid.x;
# 	add.s32 	%r4, %r1, 1;
# 	cvt.u64.u32 	%rd9, %r4;
# 	add.s64 	%rd2, %rd1, %rd9;
# 	ld.u64 	%rd10, [%rd6];
# 	max.s64 	%rd11, %rd10, 0;
# 	setp.le.s64 	%p1, %rd2, %rd11;
# 	@%p1 bra 	LBB0_2;
# // %bb.1:                               // %L48
# 	{ // callseq 5, 0
# 	.reg .b32 temp_param_reg;
# 	call.uni
# 	ptx_throw_boundserror,
# 	(
# 	);
# 	} // callseq 5
# LBB0_2:                                 // %L51
# 	ld.param.u64 	%rd8, [julia_vadd_37900_param_2];
# 	ld.u64 	%rd12, [%rd6+8];
# 	cvt.u64.u32 	%rd13, %r1;
# 	add.s64 	%rd14, %rd1, %rd13;
# 	add.s64 	%rd3, %rd14, -1;
# 	shl.b64 	%rd15, %rd3, 3;
# 	add.s64 	%rd16, %rd12, %rd15;
# 	add.s64 	%rd17, %rd16, 8;
# 	cvta.to.global.u64 	%rd18, %rd17;
# 	ld.global.u64 	%rd4, [%rd18];
# 	ld.u64 	%rd19, [%rd7];
# 	max.s64 	%rd20, %rd19, 0;
# 	setp.le.s64 	%p2, %rd2, %rd20;
# 	@%p2 bra 	LBB0_4;
# // %bb.3:                               // %L68
# 	{ // callseq 6, 0
# 	.reg .b32 temp_param_reg;
# 	call.uni
# 	ptx_throw_boundserror,
# 	(
# 	);
# 	} // callseq 6
# LBB0_4:                                 // %L71
# 	ld.u64 	%rd21, [%rd7+8];
# 	add.s64 	%rd23, %rd21, %rd15;
# 	add.s64 	%rd24, %rd23, 8;
# 	cvta.to.global.u64 	%rd25, %rd24;
# 	ld.global.u64 	%rd5, [%rd25];
# 	ld.u64 	%rd26, [%rd8];
# 	max.s64 	%rd27, %rd26, 0;
# 	setp.le.s64 	%p3, %rd2, %rd27;
# 	@%p3 bra 	LBB0_6;
# // %bb.5:                               // %L89
# 	{ // callseq 7, 0
# 	.reg .b32 temp_param_reg;
# 	call.uni
# 	ptx_throw_boundserror,
# 	(
# 	);
# 	} // callseq 7
# LBB0_6:                                 // %L92
# 	add.s64 	%rd28, %rd5, %rd4;
# 	ld.u64 	%rd29, [%rd8+8];
# 	add.s64 	%rd31, %rd29, %rd15;
# 	add.s64 	%rd32, %rd31, 8;
# 	cvta.to.global.u64 	%rd33, %rd32;
# 	st.global.u64 	[%rd33], %rd28;
# 	ret;
# }
#                                         // -- End function
# .func ptx_throw_boundserror()           // -- Begin function ptx_throw_boundserror
#                                         // @ptx_throw_boundserror
# {
# 	.reg .b32 	%r<2>;
# 	.reg .b64 	%rd<4>;
#
# // %bb.0:                               // %entry
# 	mov.u64 	%rd1, __unnamed_1;
# 	cvta.global.u64 	%rd2, %rd1;
# 	mov.u64 	%rd3, 0;
# 	{ // callseq 8, 0
# 	.reg .b32 temp_param_reg;
# 	.param .b64 param0;
# 	st.param.b64 	[param0+0], %rd2;
# 	.param .b64 param1;
# 	st.param.b64 	[param1+0], %rd3;
# 	.param .b32 retval0;
# 	call.uni (retval0),
# 	vprintf,
# 	(
# 	param0,
# 	param1
# 	);
# 	ld.param.b32 	%r1, [retval0+0];
# 	} // callseq 8
# 	ret;
# }
#                                         // -- End function
# 	// .globl	ptxcall_vadd_3  // -- Begin function ptxcall_vadd_3
# .visible .entry ptxcall_vadd_3(
# 	.param .align 8 .b8 ptxcall_vadd_3_param_0[16],
# 	.param .align 8 .b8 ptxcall_vadd_3_param_1[16],
# 	.param .align 8 .b8 ptxcall_vadd_3_param_2[16]
# )                                       // @ptxcall_vadd_3
# {
# 	.local .align 8 .b8 	__local_depot2[48];
# 	.reg .b64 	%SP;
# 	.reg .b64 	%SPL;
# 	.reg .b64 	%rd<13>;
#
# // %bb.0:                               // %entry
# 	mov.u64 	%SPL, __local_depot2;
# 	cvta.local.u64 	%SP, %SPL;
# 	ld.param.u64 	%rd1, [ptxcall_vadd_3_param_0+8];
# 	ld.param.u64 	%rd2, [ptxcall_vadd_3_param_0];
# 	ld.param.u64 	%rd3, [ptxcall_vadd_3_param_1+8];
# 	ld.param.u64 	%rd4, [ptxcall_vadd_3_param_1];
# 	add.u64 	%rd5, %SP, 0;
# 	add.u64 	%rd6, %SPL, 0;
# 	ld.param.u64 	%rd7, [ptxcall_vadd_3_param_2+8];
# 	ld.param.u64 	%rd8, [ptxcall_vadd_3_param_2];
# 	st.local.u64 	[%rd6], %rd2;
# 	st.local.u64 	[%rd6+8], %rd1;
# 	add.u64 	%rd9, %SP, 16;
# 	add.u64 	%rd10, %SPL, 16;
# 	st.local.u64 	[%rd10], %rd4;
# 	st.local.u64 	[%rd10+8], %rd3;
# 	add.u64 	%rd11, %SP, 32;
# 	add.u64 	%rd12, %SPL, 32;
# 	st.local.u64 	[%rd12], %rd8;
# 	st.local.u64 	[%rd12+8], %rd7;
# 	{ // callseq 9, 0
# 	.reg .b32 temp_param_reg;
# 	.param .b64 param0;
# 	st.param.b64 	[param0+0], %rd5;
# 	.param .b64 param1;
# 	st.param.b64 	[param1+0], %rd9;
# 	.param .b64 param2;
# 	st.param.b64 	[param2+0], %rd11;
# 	call.uni
# 	julia_vadd_37900,
# 	(
# 	param0,
# 	param1,
# 	param2
# 	);
# 	} // callseq 9
# 	ret;
# }
#                                         // -- End function

# %% [markdown]
# It's fast! We outperform `nvcc` on Rodinia benchmark suite.

# %% [markdown]
# ![CUDAnative performance](img/cudanative_perf.png)

# %% [markdown]
# # CuArrays.jl

# %% [markdown]
# Array-based abstractions of GPU computations:

# %%
a = CuArray(rand(2,2))
b = CuArray(rand(2,2))
# Out:
# 2×2 CuArray{Float64,2}:
#  0.560497   0.248382
#  0.0249621  0.0141561

# %%
a * b
# Out:
# 2×2 CuArray{Float64,2}:
#  0.478548  0.213071
#  0.221448  0.098413

# %% [markdown]
# But we have a Julia to GPU compiler! Which makes our abstractions **much more powerful**:

# %%
reduce(+, a)
# Out:
# 1.6450283402849906

# %%
map((x,y) -> x*y, a, b)
# Out:
# 2×2 CuArray{Float64,2}:
#  0.47045     0.0805833
#  0.00976213  0.0012765

# %% [markdown]
# Generalized to `broadcast`, where shapes are extended:

# %%
c = CuArray(rand(2))
broadcast((x,y) -> x*y, a, c)
# Out:
# 2×2 CuArray{Float64,2}:
#  0.51599    0.199446
#  0.0200414  0.00462107

# %% [markdown]
# Convenient short-hand syntax:

# %%
a .* c
# Out:
# 2×2 CuArray{Float64,2}:
#  0.51599    0.199446
#  0.0200414  0.00462107

# %%
@device_code_ptx a .* c
# Out:
# //
# // Generated by LLVM NVPTX Back-End
# //
#
# .version 6.0
# .target sm_35
# .address_size 64
#
# .extern .func  (.param .b32 func_retval0) vprintf
# (
# 	.param .b64 vprintf_param_0,
# 	.param .b64 vprintf_param_1
# )
# ;
# .extern .func jl_gc_queue_root
# (
# 	.param .b64 jl_gc_queue_root_param_0
# )
# ;
# .extern .func  (.param .b64 func_retval0) jl_gc_pool_alloc
# (
# 	.param .b64 jl_gc_pool_alloc_param_0,
# 	.param .b32 jl_gc_pool_alloc_param_1,
# 	.param .b32 jl_gc_pool_alloc_param_2
# )
# ;
# .extern .func  (.param .b64 func_retval0) jl_gc_big_alloc
# (
# 	.param .b64 jl_gc_big_alloc_param_0,
# 	.param .b64 jl_gc_big_alloc_param_1
# )
# ;
# .global .align 1 .b8 __unnamed_1[38] = {69, 82, 82, 79, 82, 58, 32, 97, 110, 32, 117, 110, 107, 110, 111, 119, 110, 32, 101, 120, 99, 101, 112, 116, 105, 111, 110, 32, 111, 99, 99, 117, 114, 114, 101, 100, 10, 0};
#                                         // -- Begin function julia__25_38117
#                                         // @julia__25_38117
# .func julia__25_38117(
# 	.param .b64 julia__25_38117_param_0,
# 	.param .b64 julia__25_38117_param_1,
# 	.param .b64 julia__25_38117_param_2
# )
# {
# 	.reg .pred 	%p<11>;
# 	.reg .b16 	%rs<4>;
# 	.reg .b32 	%r<9>;
# 	.reg .f64 	%fd<4>;
# 	.reg .b64 	%rd<57>;
#
# // %bb.0:                               // %top
# 	ld.param.u64 	%rd10, [julia__25_38117_param_1];
# 	mov.u32 	%r2, %ctaid.x;
# 	mov.u32 	%r3, %ntid.x;
# 	mul.wide.u32 	%rd2, %r3, %r2;
# 	mov.u32 	%r1, %tid.x;
# 	add.s32 	%r4, %r1, 1;
# 	cvt.u64.u32 	%rd13, %r4;
# 	add.s64 	%rd3, %rd2, %rd13;
# 	ld.u64 	%rd4, [%rd10];
# 	ld.u64 	%rd14, [%rd10+8];
# 	mul.lo.s64 	%rd15, %rd14, %rd4;
# 	setp.ge.s64 	%p1, %rd15, %rd3;
# 	@%p1 bra 	LBB0_2;
# 	bra.uni 	LBB0_1;
# LBB0_2:                                 // %L22
# 	add.s64 	%rd5, %rd3, -1;
# 	setp.ne.s64 	%p2, %rd5, -9223372036854775808;
# 	setp.ne.s64 	%p3, %rd4, -1;
# 	or.pred  	%p4, %p2, %p3;
# 	setp.ne.s64 	%p5, %rd4, 0;
# 	and.pred  	%p6, %p5, %p4;
# 	@%p6 bra 	LBB0_4;
# // %bb.3:                               // %fail
# 	mov.u64 	%rd12, __unnamed_1;
# 	cvta.global.u64 	%rd1, %rd12;
# 	mov.u64 	%rd16, 0;
# 	{ // callseq 21, 0
# 	.reg .b32 temp_param_reg;
# 	.param .b64 param0;
# 	st.param.b64 	[param0+0], %rd1;
# 	.param .b64 param1;
# 	st.param.b64 	[param1+0], %rd16;
# 	.param .b32 retval0;
# 	call.uni (retval0),
# 	vprintf,
# 	(
# 	param0,
# 	param1
# 	);
# 	ld.param.b32 	%r5, [retval0+0];
# 	} // callseq 21
# LBB0_4:                                 // %pass
# 	ld.param.u64 	%rd11, [julia__25_38117_param_2];
# 	ld.param.u64 	%rd9, [julia__25_38117_param_0];
# 	or.b64  	%rd17, %rd5, %rd4;
# 	and.b64  	%rd18, %rd17, -4294967296;
# 	setp.ne.s64 	%p7, %rd18, 0;
# 	@%p7 bra 	LBB0_6;
# 	bra.uni 	LBB0_5;
# LBB0_6:
# 	div.s64 	%rd56, %rd5, %rd4;
# 	bra.uni 	LBB0_7;
# LBB0_5:
# 	cvt.u32.u64 	%r6, %rd4;
# 	cvt.u32.u64 	%r7, %rd5;
# 	div.u32 	%r8, %r7, %r6;
# 	cvt.u64.u32 	%rd56, %r8;
# LBB0_7:
# 	mul.lo.s64 	%rd19, %rd4, %rd56;
# 	sub.s64 	%rd20, %rd5, %rd19;
# 	add.s64 	%rd21, %rd20, 1;
# 	add.s64 	%rd22, %rd56, 1;
# 	ld.u8 	%rs1, [%rd11+24];
# 	setp.eq.s16 	%p8, %rs1, 0;
# 	ld.u64 	%rd23, [%rd11+32];
# 	selp.b64 	%rd24, %rd23, %rd21, %p8;
# 	ld.u8 	%rs2, [%rd11+25];
# 	setp.eq.s16 	%p9, %rs2, 0;
# 	ld.u64 	%rd25, [%rd11+40];
# 	selp.b64 	%rd26, %rd25, %rd22, %p9;
# 	ld.u64 	%rd27, [%rd11];
# 	max.s64 	%rd28, %rd27, 0;
# 	add.s64 	%rd29, %rd26, -1;
# 	mul.lo.s64 	%rd30, %rd28, %rd29;
# 	ld.u64 	%rd31, [%rd11+16];
# 	add.s64 	%rd32, %rd24, %rd30;
# 	shl.b64 	%rd33, %rd32, 3;
# 	add.s64 	%rd34, %rd31, %rd33;
# 	add.s64 	%rd35, %rd34, -8;
# 	cvta.to.global.u64 	%rd36, %rd35;
# 	ld.global.f64 	%fd1, [%rd36];
# 	ld.u8 	%rs3, [%rd11+64];
# 	setp.eq.s16 	%p10, %rs3, 0;
# 	ld.u64 	%rd37, [%rd11+72];
# 	selp.b64 	%rd38, %rd37, %rd21, %p10;
# 	ld.u64 	%rd39, [%rd11+56];
# 	shl.b64 	%rd40, %rd38, 3;
# 	add.s64 	%rd41, %rd39, %rd40;
# 	add.s64 	%rd42, %rd41, -8;
# 	cvta.to.global.u64 	%rd43, %rd42;
# 	ld.global.f64 	%fd2, [%rd43];
# 	mul.f64 	%fd3, %fd1, %fd2;
# 	max.s64 	%rd44, %rd4, 0;
# 	mul.lo.s64 	%rd45, %rd44, %rd56;
# 	ld.u64 	%rd46, [%rd10+16];
# 	cvt.u64.u32 	%rd47, %r1;
# 	add.s64 	%rd48, %rd2, %rd47;
# 	add.s64 	%rd49, %rd48, -1;
# 	sub.s64 	%rd50, %rd49, %rd19;
# 	add.s64 	%rd51, %rd45, %rd50;
# 	shl.b64 	%rd52, %rd51, 3;
# 	add.s64 	%rd53, %rd46, %rd52;
# 	add.s64 	%rd54, %rd53, 8;
# 	cvta.to.global.u64 	%rd55, %rd54;
# 	st.global.f64 	[%rd55], %fd3;
# 	st.f64 	[%rd9], %fd3;
# LBB0_1:                                 // %L21
# 	ret;
# }
#                                         // -- End function
# 	// .globl	ptxcall_anonymous_7 // -- Begin function ptxcall_anonymous_7
# .visible .entry ptxcall_anonymous_7(
# 	.param .align 8 .b8 ptxcall_anonymous_7_param_0[24],
# 	.param .align 8 .b8 ptxcall_anonymous_7_param_1[96]
# )                                       // @ptxcall_anonymous_7
# {
# 	.local .align 8 .b8 	__local_depot1[128];
# 	.reg .b64 	%SP;
# 	.reg .b64 	%SPL;
# 	.reg .b16 	%rs<4>;
# 	.reg .b64 	%rd<24>;
#
# // %bb.0:                               // %entry
# 	mov.u64 	%SPL, __local_depot1;
# 	cvta.local.u64 	%SP, %SPL;
# 	ld.param.u64 	%rd1, [ptxcall_anonymous_7_param_0+16];
# 	ld.param.u64 	%rd2, [ptxcall_anonymous_7_param_0+8];
# 	ld.param.u64 	%rd3, [ptxcall_anonymous_7_param_0];
# 	ld.param.u64 	%rd4, [ptxcall_anonymous_7_param_1+88];
# 	ld.param.u64 	%rd5, [ptxcall_anonymous_7_param_1+80];
# 	ld.param.u64 	%rd6, [ptxcall_anonymous_7_param_1+72];
# 	ld.param.u8 	%rs1, [ptxcall_anonymous_7_param_1+64];
# 	ld.param.u64 	%rd7, [ptxcall_anonymous_7_param_1+56];
# 	ld.param.u64 	%rd8, [ptxcall_anonymous_7_param_1+48];
# 	ld.param.u64 	%rd9, [ptxcall_anonymous_7_param_1+40];
# 	ld.param.u64 	%rd10, [ptxcall_anonymous_7_param_1+32];
# 	ld.param.v2.u8 	{%rs2, %rs3}, [ptxcall_anonymous_7_param_1+24];
# 	ld.param.u64 	%rd11, [ptxcall_anonymous_7_param_1+16];
# 	ld.param.u64 	%rd12, [ptxcall_anonymous_7_param_1+8];
# 	ld.param.u64 	%rd13, [ptxcall_anonymous_7_param_1];
# 	add.u64 	%rd14, %SP, 8;
# 	add.u64 	%rd15, %SPL, 8;
# 	st.local.u64 	[%rd15], %rd3;
# 	st.local.u64 	[%rd15+8], %rd2;
# 	st.local.u64 	[%rd15+16], %rd1;
# 	add.u64 	%rd16, %SP, 32;
# 	add.u64 	%rd17, %SPL, 32;
# 	st.local.u64 	[%rd17], %rd13;
# 	st.local.u64 	[%rd17+8], %rd12;
# 	st.local.u64 	[%rd17+16], %rd11;
# 	st.local.v2.u8 	[%rd17+24], {%rs2, %rs3};
# 	shr.u64 	%rd18, %rd10, 32;
# 	st.local.u32 	[%rd17+36], %rd18;
# 	st.local.u32 	[%rd17+32], %rd10;
# 	shr.u64 	%rd19, %rd9, 32;
# 	st.local.u32 	[%rd17+44], %rd19;
# 	st.local.u32 	[%rd17+40], %rd9;
# 	shr.u64 	%rd20, %rd8, 32;
# 	st.local.u32 	[%rd17+52], %rd20;
# 	st.local.u32 	[%rd17+48], %rd8;
# 	shr.u64 	%rd21, %rd7, 32;
# 	st.local.u32 	[%rd17+60], %rd21;
# 	st.local.u32 	[%rd17+56], %rd7;
# 	st.local.u8 	[%rd17+64], %rs1;
# 	shr.u64 	%rd22, %rd6, 32;
# 	st.local.u32 	[%rd17+76], %rd22;
# 	st.local.u32 	[%rd17+72], %rd6;
# 	st.local.u64 	[%rd17+80], %rd5;
# 	st.local.u64 	[%rd17+88], %rd4;
# 	add.u64 	%rd23, %SP, 0;
# 	{ // callseq 22, 0
# 	.reg .b32 temp_param_reg;
# 	.param .b64 param0;
# 	st.param.b64 	[param0+0], %rd23;
# 	.param .b64 param1;
# 	st.param.b64 	[param1+0], %rd14;
# 	.param .b64 param2;
# 	st.param.b64 	[param2+0], %rd16;
# 	call.uni
# 	julia__25_38117,
# 	(
# 	param0,
# 	param1,
# 	param2
# 	);
# 	} // callseq 22
# 	ret;
# }
#                                         // -- End function

# %% [markdown]
# Expressions **fused together** into single applications:

# %%
Meta.@lower sin.(a .* c .- c)
# Out:
# :($(Expr(:thunk, CodeInfo(
# │ 1 ─ %1 = (Base.getproperty)(Base.Broadcast, :materialize)
# │ │   %2 = (Base.getproperty)(Base.Broadcast, :broadcasted)
# │ │   %3 = (Base.getproperty)(Base.Broadcast, :broadcasted)
# │ │   %4 = (Base.getproperty)(Base.Broadcast, :broadcasted)
# │ │   %5 = (%4)(*, a, c)
# │ │   %6 = (%3)(-, %5, c)
# │ │   %7 = (%2)(sin, %6)
# │ │   %8 = (%1)(%7)
# │ └──      return %8
# ))))
